# %% [markdown]
# * 上記の x と y のndarrayを利用してください
# * このデータの散布図グラフを描いてください：
#   * 横軸が x 、縦軸は y としてください
#   * 散布図の点は青色にしてください
# * 最小二乗法を利用して、このデータの近似直線を散布図と一緒に描いてください：
#   * 直線は赤色にしてください
# * 横軸と縦軸それぞれのラベルを表示してください：
#   * 横軸のラベルは english としてください
#   * 縦軸のラベルは math としてください
# * 凡例を表示してください：
#   * 表示する位置は、左上としてください
#   * 表示する文字列は、散布図のほうは score、近似直線のほうは lsm としてください

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([62, 95, 83, 100, 72, 71, 55, 85, 67, 75])   # english
y = np.array([62, 80, 85, 95, 58, 76, 52, 84, 67, 71])    # math

p = np.polyfit(x, y, 1)  # 1次の多項式でフィッティング
f = np.poly1d(p)  # 多項式の関数を生成
print(f(x))

plt.scatter(x, y, color='blue')

plt.plot(x, f(x), color='red')

plt.xlabel("English")
plt.ylabel("Math")

plt.legend(loc='upper left', labels=['score', 'lsm'])

plt.show()
# Out:
# [60.76103042 88.61523705 78.48643464 92.83557139 69.2016991  68.35763223
#  54.85256235 80.17456837 64.98136476 71.7338997 ]
